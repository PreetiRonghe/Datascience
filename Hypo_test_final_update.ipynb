# %% [markdown]
# <a href="https://colab.research.google.com/github/PreetiRonghe/Datascience/blob/main/Hypo_test_final_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# import numpy as np
import scipy
from scipy import stats
import plotly.figure_factory as ff

# %%
################One-Way Anova Test ################
cof=pd.read_excel("ContractRenewal_Data.xlsx")
print(cof)
stats.f_oneway(cof.iloc[:,0], cof.iloc[:,1],cof.iloc[:,2])
# Out:
#      Supplier A  Supplier B  Supplier C
# 0          6.15        7.87        7.41
# 1          6.22        5.21        3.61
# 2          6.76        7.94        7.23
# 3          4.29        7.36        5.53
# 4          7.08        6.17        3.97
# ..          ...         ...         ...
# 115        5.85        4.53        4.27
# 116        5.04        8.06        6.39
# 117        5.68        7.14        4.60
# 118        4.77        4.84        6.15
# 119        3.57        4.55        5.28
#
# [120 rows x 3 columns]
# F_onewayResult(statistic=np.float64(2.280378701368123), pvalue=np.float64(0.10373295731933224))

# %%
################Chi-Square Test ################

Bahaman=pd.read_excel("Bahaman.xlsx")
Bahaman
# Out:
#      Defective     Country
# 0            0       India
# 1            0       India
# 2            0       India
# 3            0       India
# 4            1       India
# ..         ...         ...
# 795          0  Bangladesh
# 796          0  Bangladesh
# 797          1  Bangladesh
# 798          0  Bangladesh
# 799          0  Bangladesh
#
# [800 rows x 2 columns]

# %%
count=pd.crosstab(Bahaman["Defective"],Bahaman["Country"])
count
# Out:
# Country    Bangladesh  China  India  Srilanka
# Defective
# 0                 183    179    175       178
# 1                  17     21     25        22

# %%
Chisquares_results=scipy.stats.chi2_contingency(count)
Chisquares_results
# Out:
# Chi2ContingencyResult(statistic=np.float64(1.7243932538050184), pvalue=np.float64(0.6315243037546223), dof=3, expected_freq=array([[178.75, 178.75, 178.75, 178.75],
#        [ 21.25,  21.25,  21.25,  21.25]]))

# %%
Chi_square=[['','Test Statistic','p-value'],['Sample Data',Chisquares_results[0],Chisquares_results[1]]]
Chi_square
# Out:
# [['', 'Test Statistic', 'p-value'],
#  ['Sample Data',
#   np.float64(1.7243932538050184),
#   np.float64(0.6315243037546223)]]

# %%
chisample_results=ff.create_table(Chi_square,index=True)
chisample_results
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b1a131c3-a623-48ef-9b06-a1f13daf35fc" class="plotly-graph-div" style="height:110px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1a131c3-a623-48ef-9b06-a1f13daf35fc")) {                    Plotly.newPlot(                        "b1a131c3-a623-48ef-9b06-a1f13daf35fc",                        [{"colorscale":[[0,"#00083e"],[0.5,"#ededee"],[1,"#ffffff"]],"hoverinfo":"none","opacity":0.75,"showscale":false,"z":[[0,0,0],[0,0.5,0.5]],"type":"heatmap"}],                        {"annotations":[{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003e\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eTest Statistic\u003c\u002fb\u003e","x":0.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003ep-value\u003c\u002fb\u003e","x":1.55,"xanchor":"left","xref":"x","y":0,"yref":"y"},{"align":"left","font":{"color":"#ffffff"},"showarrow":false,"text":"\u003cb\u003eSample Data\u003c\u002fb\u003e","x":-0.45,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"1.7243932538050184","x":0.55,"xanchor":"left","xref":"x","y":1,"yref":"y"},{"align":"left","font":{"color":"#000000"},"showarrow":false,"text":"0.6315243037546223","x":1.55,"xanchor":"left","xref":"x","y":1,"yref":"y"}],"height":110,"margin":{"b":0,"l":0,"r":0,"t":0},"xaxis":{"dtick":1,"gridwidth":2,"showticklabels":false,"tick0":-0.5,"ticks":"","zeroline":false},"yaxis":{"autorange":"reversed","dtick":1,"gridwidth":2,"showticklabels":false,"tick0":0.5,"ticks":"","zeroline":false},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888888 ...

# %%
############2 sample T Test(Marketing Strategy) ##################
#############Normality test###############
#promotion=pd.read_excel("C:\Datasets_BA\Hypothesis\Hypothesis Testing_R&Python_codes\Promotion.xlsx")

#promotion=pd.read_excel("Promotion - Copy.xlsx")
#promotion
#print(promotion.columns)
#promotion['Interest Rate Waiver ($ spent)']
#promotion['Standard Promotion ($ spent)']

# %%
#import statsmodels
#print(stats.shapiro(promotion['Interest Rate Waiver ($ spent)'] ))
#print(stats.shapiro(promotion['Standard Promotion ($ spent)'] ))
#print(scipy.stats.ttest_ind(promotion['Interest Rate Waiver ($ spent)'], promotion['Standard Promotion ($ spent)']))
#statsmodels.stats.weightstats.ttest_ind(promotion['Interest Rate Waiver ($ spent)'], promotion['Standard Promotion ($ spent)'], alternative='larger',usevar='unequal')

# %%
#from statsmodels.formula.api import ols
#cof=pd.read_excel("ContractRenewal_Data(unstacked).xlsx")
#print(cof)
#cof.columns="SupplierA","SupplierB","SupplierC"
##########Normality Test ############
#print(stats.shapiro(cof.SupplierA))    #Shapiro Test
#print(stats.shapiro(cof.SupplierB))
#print(stats.shapiro(cof.SupplierC))
############## Variance test #########
#print(scipy.stats.levene(cof.SupplierA, cof.SupplierB))
#print(scipy.stats.levene(cof.SupplierB, cof.SupplierC))
#print(scipy.stats.levene(cof.SupplierC, cof.SupplierA))

# %%
############# One - Way Anova###################
#mod=ols('SupplierA ~ (SupplierB + SupplierC)',data=cof).fit()
#aov_table=sm.stats.anova_lm(mod)
#print(aov_table)
#stats.f_oneway(cof.iloc[:,0], cof.iloc[:,1],cof.iloc[:,2])
