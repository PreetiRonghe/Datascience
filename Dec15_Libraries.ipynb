# %% [markdown]
# <a href="https://colab.research.google.com/github/PreetiRonghe/Datascience/blob/main/Dec15_Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Numpy - numerical python. When performing mathematical operations in numpy the processing is faster as list and data elements are stored in continuous locations
#Pandas- data manipulation
#Preprocessing of structured data-
#Series - 1 Column
#Dataframe - Multiple Columns
#Matplotlib - Visualization(EDA)  for data analysis
#pyplot has visualization methods
#so for visualization can we we use seaborn
