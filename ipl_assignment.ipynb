# %% [markdown]
# <a href="https://colab.research.google.com/github/PreetiRonghe/Datascience/blob/main/ipl_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ipl_auction_df = pd.read_csv('IPL IMB381IPL2013.csv')
display(ipl_auction_df.head(10))
display(ipl_auction_df.tail(10))
display(ipl_auction_df.info())
display(ipl_auction_df.shape)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
type(ipl_auction_df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_columns', 7)

# %%
list(ipl_auction_df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
ipl_auction_df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
 ipl_auction_df.shape
# Out:
# (130, 26)

# %%
ipl_auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
ipl_auction_df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 0       1   Abdulla, YA    2  ...         2009      50000      50000
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
#
# [5 rows x 26 columns]

# %%
ipl_auction_df[1:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 1       2  Abdur Razzak    2  ...         2008      50000      50000
# 2       3   Agarkar, AB    2  ...         2008     200000     350000
# 3       4     Ashwin, R    1  ...         2011     100000     850000
# 4       5  Badrinath, S    2  ...         2011     100000     800000
#
# [4 rows x 26 columns]

# %%
ipl_auction_df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 125     126     Yadav, AS    2  ...         2010      50000     750000
# 126     127   Younis Khan    2  ...         2008     225000     225000
# 127     128  Yuvraj Singh    2  ...         2011     400000    1800000
# 128     129   Zaheer Khan    2  ...         2008     200000     450000
# 129     130    Zoysa, DNT    2  ...         2008     100000     110000
#
# [5 rows x 26 columns]

# %%
ipl_auction_df[-1:]
# Out:
#      Sl.NO. PLAYER NAME  AGE  ... AUCTION YEAR BASE PRICE SOLD PRICE
# 129     130  Zoysa, DNT    2  ...         2008     100000     110000
#
# [1 rows x 26 columns]

# %%
 ipl_auction_df['PLAYER NAME'][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
 ipl_auction_df[['PLAYER NAME', 'COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
 #I didnt get it
 ipl_auction_df.iloc[4:9, 1:4]
# Out:
#      PLAYER NAME  AGE COUNTRY
# 4   Badrinath, S    2     IND
# 5     Bailey, GJ    2     AUS
# 6      Balaji, L    2     IND
# 7  Bollinger, DE    2     AUS
# 8       Botha, J    2      SA

# %%
#gives Count of Country player
ipl_auction_df.COUNTRY.value_counts()
# Out:
# COUNTRY
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: count, dtype: int64

# %%
ipl_auction_df.COUNTRY.value_counts(normalize=True)*100
# Out:
# COUNTRY
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: proportion, dtype: float64

# %%
pd.crosstab( ipl_auction_df['AGE'], ipl_auction_df['PLAYING ROLE'] )
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
ipl_auction_df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE')[0:5]
# Out:
#       PLAYER NAME  SOLD PRICE
# 73     Noffke, AA       20000
# 46    Kamran Khan       24000
# 5      Bailey, GJ       50000
# 0     Abdulla, YA       50000
# 34  Henriques, MC       50000

# %%
ipl_auction_df[['PLAYER NAME', 'SOLD PRICE']].sort_values('SOLD PRICE', ascending = False)[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 93       Sehwag, V     1800000
# 113     Tiwary, SS     1600000

# %%
ipl_auction_df[['PLAYER NAME', 'SOLD PRICE']].sort_values('SOLD PRICE', ascending = True)[0:5]
# Out:
#       PLAYER NAME  SOLD PRICE
# 73     Noffke, AA       20000
# 46    Kamran Khan       24000
# 5      Bailey, GJ       50000
# 0     Abdulla, YA       50000
# 34  Henriques, MC       50000

# %%
ipl_auction_df['premium'] =  ipl_auction_df['SOLD PRICE'] - ipl_auction_df['BASE PRICE']
display('premium', ipl_auction_df['premium'].head(5))
# Out:
# 'premium'
# 0         0
# 1         0
# 2    150000
# 3    750000
# 4    700000
# Name: premium, dtype: int64
