# %% [markdown]
# <a href="https://colab.research.google.com/github/PreetiRonghe/Datascience/blob/main/19NovemberVAC_DS_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#19-November-2025
print("Pr!")
# Out:
# Pr!

# %%
#Today is the first day
#python in an expressive language
#comments : are those line which wont be executed
#Other than codes

# %%
#Variable : A container where we store the data

# %%
var1 = 12
var2 = 45
# value of variable 1 is 12 and value of variable 2 is 45
#f : is used for formatting the print stmnt to put a value from variable
print("value of variable 1 is",var1,"value of variable 2 is ",var2,".")
print(f"value of variable 1 is {var1} value of variable 2 is {var2}.")
#in order to optimize the print statement use f when you want to use formatting. you can get rid of a lot of , and""
#if you use f pass your variables in curly braces
# Out:
# value of variable 1 is 12 value of variable 2 is  45 .
# value of variable 1 is 12 value of variable 2 is 45.

# %%
#datatype:defines the form of storage
#example : int , float , string , boolean
var1 = 300 #int
var2 = 300.67 #float
var3 = "Watch" #String
var4 = True # boolean
#use Type function
print(type(var1))
print(type(var2))
print(type(var3))
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
var1= 34
print(var1)#34
var1=45
print(var1)#45
var1 = 600
print(var1)#600
# Out:
# 34
# 45
# 600

# %%
#variables stores only one data at a atime
 #so we need collection or sequence
 #Datatypes are used to store multiple values of data
#There are majorly 4 types of Datatypes:
#List []
#Function
#'append',
 #'clear',
 #'copy',
 #'count',
 #'extend',
 #'index',
 #'insert',
 #'pop',
 #'remove',
 #'reverse',
 #'sort'
#Tuples ()
#Sets {}
#Dictionaries{}

data1 = [12,34,56,78,90]
print("List:",type(data1))
dir(data1)
# Out:
# List: <class 'list'>
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
data2 = (12,34,56,78,90)
print("Tuple :",type(data2))
# Out:
# Tuple : <class 'tuple'>

# %%
data3 = {12,34,56,78,90}
print("SET :",type(data3))
# Out:
# SET : <class 'set'>

# %%
data4 = {"Name":"Tasmiya","Location":"Mumbai"}
print("Dict :",type(data4))
# Out:
# Dict : <class 'dict'>
