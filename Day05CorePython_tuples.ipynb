# %% [markdown]
# <a href="https://colab.research.google.com/github/PreetiRonghe/Datascience/blob/main/Day05CorePython_tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Include Details about Mutable and Immutable Datatypes and Data Structure
#Tuples are immutable
#it is used creating round brackets
t1=(1,2,3,4,5,5,6,7,8,6,6)
print(t1)
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6)

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
type(t1)
# Out:
# tuple

# %%
t1[3]
# Out:
# 4

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6)

# %%
t1[0]=100
#tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-469800251.py in <cell line: 0>()
# ----> 1 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6)

# %%
t2=(6,7,8,9)

# %%
t3=t1+t2

# %%
t3
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6, 6, 7, 8, 9)

# %%
t3*2
# Out:
# (1,
#  2,
#  3,
#  4,
#  5,
#  5,
#  6,
#  7,
#  8,
#  6,
#  6,
#  6,
#  7,
#  8,
#  9,
#  1,
#  2,
#  3,
#  4,
#  5,
#  5,
#  6,
#  7,
#  8,
#  6,
#  6,
#  6,
#  7,
#  8,
#  9)

# %%
t3
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6, 6, 7, 8, 9)

# %%
t3.count(5)
# Out:
# 2

# %%
t3.index(7)
# Out:
# 7

# %%
t1[1:4]
# Out:
# (2, 3, 4)

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6)

# %%
t1[3:8]
# Out:
# (4, 5, 5, 6, 7)

# %%
t1[0:-1]
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6)

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8, 6, 6)

# %%
t1[0:-2]
# Out:
# (1, 2, 3, 4, 5, 5, 6, 7, 8)
