# %% [markdown]
# <a href="https://colab.research.google.com/github/PreetiRonghe/Datascience/blob/main/Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tuple
# Tuples aare a datatype
#
# 1. they are read -only
# 2. they are immutable
# 3. ()
# 4. Heterogeneous data type
# 5. You cant add, update, delete
# 6. only Index ,Count and Find
#
#
#
#
#  #List
#  It anticipates that,there will be List Modification Operation so for a list it allocates more space

# %%
Tuple1=(1,2,3,4,5)
print(Tuple1)
# Out:
# (1, 2, 3, 4, 5)

# %%
tuple2=("a","b","c","d","hello",1.3,1,2,3,4,5,2,2,3,4,5,(1,2,3))
print(tuple2)
# Out:
# ('a', 'b', 'c', 'd', 'hello', 1.3, 1, 2, 3, 4, 5, 2, 2, 3, 4, 5, (1, 2, 3))

# %%
for i in tuple2:
  print(i)
# Out:
# a
# b
# c
# d
# hello
# 1.3
# 1
# 2
# 3
# 4
# 5
# 2
# 2
# 3
# 4
# 5
# (1, 2, 3)

# %%
tupleaslist=list(tuple2)
print(tupleaslist)
# Out:
# ['a', 'b', 'c', 'd', 'hello', 1.3, 1, 2, 3, 4, 5, 2, 2, 3, 4, 5, (1, 2, 3)]

# %%
#Count in Tuple
print(tuple2.count(2))
# Out:
# 3

# %%
#find in tuple
print(tuple2.index(2))
# Out:
# 7

# %%
#index in Tuple
print(tuple2.index("hello"))
# Out:
# 4

# %%
#slicing in Tuple
print(tuple2[0:5])
# Out:
# ('a', 'b', 'c', 'd', 'hello')

# %%
#add in Tuple
tuple2.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-471860820.py in <cell line: 0>()
#       1 #add in Tuple
# ----> 2 tuple2.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'
